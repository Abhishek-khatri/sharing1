# %%
import matplotlib.pyplot as plt
x=[2,3,1,5,6]
y=[5,8,2,1,3]
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import math
x=np.linspace(0,6*math.pi)
plt.plot(np.sin(x))
print(x)
# Out:
# [ 0.          0.38468481  0.76936963  1.15405444  1.53873926  1.92342407
#   2.30810889  2.6927937   3.07747852  3.46216333  3.84684815  4.23153296
#   4.61621778  5.00090259  5.38558741  5.77027222  6.15495704  6.53964185
#   6.92432667  7.30901148  7.69369629  8.07838111  8.46306592  8.84775074
#   9.23243555  9.61712037 10.00180518 10.38649    10.77117481 11.15585963
#  11.54054444 11.92522926 12.30991407 12.69459889 13.0792837  13.46396852
#  13.84865333 14.23333814 14.61802296 15.00270777 15.38739259 15.7720774
#  16.15676222 16.54144703 16.92613185 17.31081666 17.69550148 18.08018629
#  18.46487111 18.84955592]

# %%
import numpy as np
import math
x=np.linspace(0,6*math.pi)
plt.plot(x,np.sin(x))
print(x)
# Out:
# [ 0.          0.38468481  0.76936963  1.15405444  1.53873926  1.92342407
#   2.30810889  2.6927937   3.07747852  3.46216333  3.84684815  4.23153296
#   4.61621778  5.00090259  5.38558741  5.77027222  6.15495704  6.53964185
#   6.92432667  7.30901148  7.69369629  8.07838111  8.46306592  8.84775074
#   9.23243555  9.61712037 10.00180518 10.38649    10.77117481 11.15585963
#  11.54054444 11.92522926 12.30991407 12.69459889 13.0792837  13.46396852
#  13.84865333 14.23333814 14.61802296 15.00270777 15.38739259 15.7720774
#  16.15676222 16.54144703 16.92613185 17.31081666 17.69550148 18.08018629
#  18.46487111 18.84955592]

# %%
## colour chhange
x=[2,3,1,5,6]
y=[5,8,2,1,3]
plt.plot(x,y,'g-')
plt.show()

# %%
x=[2,3,1,5,6]
y=[5,8,2,1,3]
plt.plot(x,y,'g--')
plt.show()

# %%
x=[2,3,1,5,6]
y=[5,8,2,1,3]
plt.plot(x,y,'r--')
plt.show()

# %%
x=[2,3,1,5,6]
y=[5,8,2,1,3]
plt.plot(x,y,'ro')
plt.show()

# %%
x=[2,3,1,5,6]
y=[5,8,2,1,3]
plt.plot(x,y,'r^')
plt.show()

# %%
x=np.linspace(0,6*math.pi)
plt.plot(x,np.sin(x),'ro',x,np.sin(x),'g-')
print(x)
# Out:
# [ 0.          0.38468481  0.76936963  1.15405444  1.53873926  1.92342407
#   2.30810889  2.6927937   3.07747852  3.46216333  3.84684815  4.23153296
#   4.61621778  5.00090259  5.38558741  5.77027222  6.15495704  6.53964185
#   6.92432667  7.30901148  7.69369629  8.07838111  8.46306592  8.84775074
#   9.23243555  9.61712037 10.00180518 10.38649    10.77117481 11.15585963
#  11.54054444 11.92522926 12.30991407 12.69459889 13.0792837  13.46396852
#  13.84865333 14.23333814 14.61802296 15.00270777 15.38739259 15.7720774
#  16.15676222 16.54144703 16.92613185 17.31081666 17.69550148 18.08018629
#  18.46487111 18.84955592]

# %%
x=np.linspace(0,6*math.pi)
plt.plot(x,np.sin(x),'ro',x,np.cos(x),'g-')
print(x)
# Out:
# [ 0.          0.38468481  0.76936963  1.15405444  1.53873926  1.92342407
#   2.30810889  2.6927937   3.07747852  3.46216333  3.84684815  4.23153296
#   4.61621778  5.00090259  5.38558741  5.77027222  6.15495704  6.53964185
#   6.92432667  7.30901148  7.69369629  8.07838111  8.46306592  8.84775074
#   9.23243555  9.61712037 10.00180518 10.38649    10.77117481 11.15585963
#  11.54054444 11.92522926 12.30991407 12.69459889 13.0792837  13.46396852
#  13.84865333 14.23333814 14.61802296 15.00270777 15.38739259 15.7720774
#  16.15676222 16.54144703 16.92613185 17.31081666 17.69550148 18.08018629
#  18.46487111 18.84955592]

# %%
import matplotlib.pyplot as plt
x=[2,3,1,5,6]
y=[5,8,2,1,3]
#plot.figure()
plt.subplot(121)
plt.plot(x,y)
plt.subplot(122)
plt.plot(x,y)
plt.show()
plt.savefig('a')

# %%
import numpy as np
plt.subplot(121)
x=np.linspace(0,6*math.pi)
plt.plot(np.sin(x))
plt.subplot(122)
x=np.linspace(0,6*math.pi)
plt.plot(np.cos(x))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ea38b0db9818> in <module>()
#       1 import numpy as np
#       2 plt.subplot(121)
# ----> 3 x=np.linspace(0,6*math.pi)
#       4 plt.plot(np.sin(x))
#       5 plt.subplot(122)
#
# NameError: name 'math' is not defined
